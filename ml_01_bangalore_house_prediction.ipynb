# %%
import pandas as pd

# %%
df_ref = pd.read_csv("data/bengaluru_house_data.csv")
df_ref.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df_ref.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
# Checking for df_ref shape (Row, Columns) in reference DataFrame
df_ref.shape
# Out:
# (13320, 9)

# %%
df_a = df_ref.drop(labels = ['area_type', 'availability', 'society', 'balcony', 'price'], axis = 'columns')
df_a.head()
# Out:
#                    location       size total_sqft  bath
# 0  Electronic City Phase II      2 BHK       1056   2.0
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2               Uttarahalli      3 BHK       1440   2.0
# 3        Lingadheeranahalli      3 BHK       1521   3.0
# 4                  Kothanur      2 BHK       1200   2.0

# %%
# Checking for featurwise null values 
df_a.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# dtype: int64

# %%
# Drop rows contain NA value
df_b = df_a.dropna(axis = 'index')
df_b.head()
# Out:
#                    location       size total_sqft  bath
# 0  Electronic City Phase II      2 BHK       1056   2.0
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2               Uttarahalli      3 BHK       1440   2.0
# 3        Lingadheeranahalli      3 BHK       1521   3.0
# 4                  Kothanur      2 BHK       1200   2.0

# %%
df_b.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# dtype: int64

# %%
# Checking for df_ref shape (Row, Columns) in df_b DataFrame
df_b.shape
# Out:
# (13246, 4)

# %%
# Observing unique values in <size> feature of DataFrame <df_b>
df_b['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df_b['bhk'] = df_b['size'].apply(lambda val: val.split(' ')[0])
df_b.drop(labels = ['size'], axis = 1)
df_b.head()
# Out:
# C:\Users\mistertandon\Anaconda3\envs\applied-ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                    location       size total_sqft  bath bhk
# 0  Electronic City Phase II      2 BHK       1056   2.0   2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0   4
# 2               Uttarahalli      3 BHK       1440   2.0   3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   3
# 4                  Kothanur      2 BHK       1200   2.0   2

# %%
df_b['bhk'].unique()
# Out:
# array(['2', '4', '3', '6', '1', '8', '7', '5', '11', '9', '27', '10',
#        '19', '16', '43', '14', '12', '13', '18'], dtype=object)

# %%
# We may observe Scalar values as well as Range Values in <total_sqft> feature
df_b['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
# Let's build a function to search for Range Values
def serch_range_values(x):
    try:
        float(x)
    except:
        return False
    
    return True

# %%
df_c = df_b[~df_b['total_sqft'].apply(serch_range_values)]
df_c.head()
# Out:
#                location   size   total_sqft  bath bhk
# 30            Yelahanka  4 BHK  2100 - 2850   4.0   4
# 122              Hebbal  4 BHK  3067 - 8156   4.0   4
# 137  8th Phase JP Nagar  2 BHK  1042 - 1105   2.0   2
# 165            Sarjapur  2 BHK  1145 - 1340   2.0   2
# 188            KR Puram  2 BHK  1015 - 1540   2.0   2

# %%
import numpy as np

# %%
def range_values_to_scalar(x):
    
    tokens = x.split('-')

    if len(tokens) == 2:
        
        tokens_float = [float(token) for token in tokens]
        tokens_mean = np.mean(tokens_float)
        
        return tokens_mean
    else:
        try:
            return float(x)
        except:
            return False

# %%
df_c['total_sqft_float'] = df_c['total_sqft'].apply(range_values_to_scalar)
df_c.head(n = 3)
# Out:
# C:\Users\mistertandon\Anaconda3\envs\applied-ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                location   size   total_sqft  bath bhk total_sqft_float
# 30            Yelahanka  4 BHK  2100 - 2850   4.0   4             2475
# 122              Hebbal  4 BHK  3067 - 8156   4.0   4           5611.5
# 137  8th Phase JP Nagar  2 BHK  1042 - 1105   2.0   2           1073.5

# %%
df_c[df_c['total_sqft_float'] == False]
# Out:
#                                            location       size  \
# 410                                         Kengeri      1 BHK
# 648                                         Arekere  9 Bedroom
# 775                                    Basavanagara      1 BHK
# 872                               Singapura Village      2 BHK
# 1019                                 Marathi Layout  1 Bedroom
# 1086                                     Narasapura  2 Bedroom
# 1400                                     Chamrajpet      9 BHK
# 1712                               Singena Agrahara  3 Bedroom
# 1743                                      Hosa Road      3 BHK
# 1821                                       Sarjapur  3 Bedroom
# 2310                                     Whitefield      4 BHK
# 2881                             Volagerekallahalli      2 BHK
# 3228                                Dodda Banaswadi  5 Bedroom
# 3285                                     Whitefield  4 Bedroom
# 4113                                     BTM Layout      3 BHK
# 4293                              Bannerghatta Road      4 BHK
# 5453                                         Kannur  6 Bedroom
# 5537                                    Frazer Town      3 BHK
# 5631                                    Thanisandra      3 BHK
# 5668                                Judicial Layout  5 Bedroom
# 5708                                         Jigani  4 Bedroom
# 5976                             1st Phase JP Nagar      1 BHK
# 6268                                       Chickpet      2 BHK
# 6303                                       JP Nagar      3 BHK
# 6333                                      Harohalli  2 Bedroom
# 6552            5 Bedroom Farm House in Lakshmipura  5 Bedroom
# 6592                                  Langford Town      4 BHK
# 6953                                      Hosa Road      3 BHK
# 7001                               Thyagaraja Nagar  8 Bedroom
# 7248                                       Hulimavu      2 BHK
# 7334                                 Kanakpura Road  1 Bedroom
# 7520                                  Doddaballapur      3 BHK
# 7607                                   Bommenahalli  3 Bedroom
# 7726                                 Kanakpura Road  1 Bedroom
# 8273                                      V.V Puram      3 BHK
# 9423                               Ramamurthy Nagar  1 Bedroom
# 9519                                   Bommenahalli  3 Bedroom
# 9734                             Yelahanka New Town      1 BHK
# 10488  2 Bedroom Furnished Farm House in Kolar Road  2 Bedroom
# 10491                                      Rajapura      2 BHK
# 11320                                 Arishinakunte  1 Bedroom
# 11615                                         arudi  3 Bedroom
# 12186                            7th Phase JP Nagar      2 BHK
# 12252                                  Gowdanapalya      5 BHK
# 12560                                     Hosa Road      3 BHK
# 12652                              Billamaranahalli  2 Bedroom
#
#             total_sqft  bath bhk total_sqft_float
# 410     34.46Sq. Meter   1.0   1            False
# 648          4125Perch   9.0   9            False
# 775      1000Sq. Meter   2.0   1            False
# 872      1100Sq. Yards   2.0   2            False
# 1019         5.31Acres   1.0   1            False
# 1086           30Acres   2.0   2            False
# 1400      716Sq. Meter   9.0   9            False
# 1712     1500Sq. Meter   3.0   3            False
# 1743   142.61Sq. Meter   3.0   3            False
# 1821     1574Sq. Yards   3.0   3            False
# 2310   361.33Sq. Yards   4.0   4            False
# 2881      117Sq. Yards   2.0   2            False
# 3228     3040Sq. Meter   5.0   5            False
# 3285      500Sq. Yards   4.0   4            False
# 4113      167Sq. Meter   3.0   3            False
# 4293      315Sq. Yards   5.0   4            False
# 5453            3Cents   6.0   6            False
# 5537   188.89Sq. Yards   3.0   3            False
# 5631      204Sq. Meter   4.0   3            False
# 5668       45Sq. Yards   6.0   5            False
# 5708    133.3Sq. Yards   3.0   4            False
# 5976    78.03Sq. Meter   1.0   1            False
# 6268      122Sq. Yards   2.0   2            False
# 6303    84.53Sq. Meter   3.0   3            False
# 6333         2.09Acres   2.0   2            False
# 6552          24Guntha   6.0   5            False
# 6592      697Sq. Meter   4.0   4            False
# 6953   142.61Sq. Meter   3.0   3            False
# 7001         1500Cents   6.0   8            False
# 7248      132Sq. Yards   2.0   2            False
# 7334            2Acres   1.0   1            False
# 7520     1100Sq. Meter   2.0   3            False
# 7607           15Acres   3.0   3            False
# 7726         1.26Acres   1.0   1            False
# 8273   151.11Sq. Yards   2.0   3            False
# 9423          1Grounds   1.0   1            False
# 9519     2940Sq. Yards   3.0   3            False
# 9734    45.06Sq. Meter   2.0   1            False
# 10488        1.25Acres   2.0   2            False
# 10491   86.72Sq. Meter   2.0   2            False
# 11320         38Guntha   1.0   1            False
# 11615           6Acres   2.0   3            False
# 12186     120Sq. Yards   2.0   2            False
# 12252      24Sq. Meter   5.0   5            False
# 12560  142.84Sq. Meter   3.0   3            False
# 12652     300Sq. Yards   2.0   2            False

# %%
# Examine feature <total_sqft_float> for <False> value
df_d = df_c[df_c['total_sqft_float'] != False]
df_d.head(n = 3)
# Out:
#                location   size   total_sqft  bath bhk total_sqft_float
# 30            Yelahanka  4 BHK  2100 - 2850   4.0   4             2475
# 122              Hebbal  4 BHK  3067 - 8156   4.0   4           5611.5
# 137  8th Phase JP Nagar  2 BHK  1042 - 1105   2.0   2           1073.5

# %%
# Examine feature <total_sqft_float> for <False> value, and verify no <False> value exist in <df_d>
df_d[df_d['total_sqft_float'] == False]
# Out:
# Empty DataFrame
# Columns: [location, size, total_sqft, bath, bhk, total_sqft_float]
# Index: []
